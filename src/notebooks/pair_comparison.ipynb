# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys

sys.path.insert(0, os.path.abspath(".."))
from dotenv import load_dotenv
import seaborn as sns
import pandas as pd
import numpy as np

from db import PostgresDB
from schemas import Proband
from cohorts import Cohort
from matplotlib import pyplot as plt

# %%
load_dotenv()
# Out:
# True

# %%
db = PostgresDB(
    db_name=os.getenv("DB_NAME"),
    host=os.getenv("DB_HOST"),
    port=os.getenv("DB_PORT"),
    user=os.getenv("DB_USER"),
)
# Out:
# Connected to database

# %% [markdown]
# ## Compare Two Hospital Stays

# %%
cohort = Cohort(db=db)

# %%
cohort.get_random_cohort(size=10)
cohort.initialize_data()
cohort.remove_encounter_with_missing_data()
cohort.similarity_encounters = cohort.similarity_encounters
# filter patients that have all categories

# %%
import pandas as pd

def create_encounter_table(encounters):
    encounters = [e.dict() for e in encounters]
    # Create an empty dataframe
    df_list = []

    # Loop through each encounter and add a row to the dataframe
    for enc in encounters:
        # Get the relevant information from the encounter dictionary
        hadm_id = enc['hadm_id']
        age = enc['demographics']['age']
        gender = enc['demographics']['gender']
        ethnicity = enc['demographics']['ethnicity']
        diagnoses = ', '.join(sorted([d['code'] for d in enc['diagnoses']]))
        labevents = ', '.join(sorted([f"{l['item_id']}: {l['value']}" for l in enc['labevents']]))
        
        # Create a sub-table for the vitalsigns column
        vitalsigns_dict = {}
        for vs in enc['vitalsigns']:
            vs_name = vs['name']
            vs_value = vs['value']
            vitalsigns_dict[vs_name] = vs_value
        vitalsigns = pd.Series(vitalsigns_dict).sort_index().to_frame().T
        vitalsigns.columns = [f"{c}_vitalsigns" for c in vitalsigns.columns]

        inputevents = ', '.join(sorted([str(i['item_id']) for i in enc['inputevents']]))

        # Add a row to the dataframe
        df_list.append([hadm_id, age, gender, ethnicity, diagnoses, labevents, inputevents])
        df_list[-1].extend(vitalsigns.values.tolist()[0])

    # Create a pandas dataframe from the list of rows
    columns = ['hadm_id', 'age', 'gender', 'ethnicity', 'diagnoses', 'labevents', 'inputevents']
    columns.extend([f"{c}_vitalsigns" for c in vitalsigns_dict.keys()])
    df = pd.DataFrame(df_list, columns=columns)

    # Order the columns and rows alphabetically
    # df = df.reindex(sorted(df.columns), axis=1)
    df = df.sort_values(by='hadm_id')
    df = df.set_index("hadm_id")

    return df

# %%
import itertools


def display_encounter_similarities(encounters):
    encounters = [e.dict() for e in encounters]
    for i, j in itertools.combinations(range(len(encounters)), 2):
        enc_i = encounters[i]
        enc_j = encounters[j]
        print(
            f"Comparing encounter {enc_i['hadm_id']} with encounter {enc_j['hadm_id']}:"
        )

        # Age difference
        age_i = enc_i["demographics"]["age"]
        age_j = enc_j["demographics"]["age"]
        print(f"Age difference: {abs(age_i - age_j)} years")

        # Gender comparison
        gender_i = enc_i["demographics"]["gender"]
        gender_j = enc_j["demographics"]["gender"]
        if gender_i == gender_j:
            print(f"Gender: {gender_i}")
        else:
            print(f"Gender difference")

        # Ethnicity comparison
        ethnicity_i = enc_i["demographics"]["ethnicity"]
        ethnicity_j = enc_j["demographics"]["ethnicity"]
        if ethnicity_i == ethnicity_j:
            print(f"Ethnicity: {ethnicity_i}")
        else:
            print("Ethnicity difference")

        # Common diagnoses
        diag_i = set([diag["code"] for diag in enc_i["diagnoses"]])
        diag_j = set([diag["code"] for diag in enc_j["diagnoses"]])
        common_diagnoses = diag_i.intersection(diag_j)
        if common_diagnoses:
            print(f"Common diagnoses codes: {', '.join(common_diagnoses)}")
        else:
            print("No common diagnoses codes")

        # Common labevents
        lab_i = {(lab["item_id"], lab["value"]) for lab in enc_i["labevents"]}
        lab_j = {(lab["item_id"], lab["value"]) for lab in enc_j["labevents"]}
        common_labevents = lab_i.intersection(lab_j)
        if common_labevents:
            print("Common labevent item ids:")
            for item_id, value in common_labevents:
                val_i = next(
                    lab["value"]
                    for lab in enc_i["labevents"]
                    if lab["item_id"] == item_id
                )
                val_j = next(
                    lab["value"]
                    for lab in enc_j["labevents"]
                    if lab["item_id"] == item_id
                )
                print(f"Item {item_id}: {abs(val_i - val_j)}")
        else:
            print("No common labevent item ids")

        # Common inputevents
        input_i = {inp["item_id"] for inp in enc_i["inputevents"]}
        input_j = {inp["item_id"] for inp in enc_j["inputevents"]}
        common_input = input_i.intersection(input_j)
        if common_input:
            print(
                f"Common inputevent item ids: {', '.join(map(str, list(common_input)))}"
            )
        else:
            print("No common inputevent item ids")

        # Vitalsigns difference
        vitals_i = {vital["id"]: vital["value"] for vital in enc_i["vitalsigns"]}
        vitals_j = {vital["id"]: vital["value"] for vital in enc_j["vitalsigns"]}
        common_vitals = set(vitals_i.keys()).intersection(set(vitals_j.keys()))
        if common_vitals:
            print("Common vitalsigns:")
            for vital_name in sorted(common_vitals):
                val_i = vitals_i[vital_name]
                val_j = vitals_j[vital_name]
                print(f"{vital_name}: {abs(val_i - val_j)}")
        else:
            print("No common vitalsigns")

        print()  # Blank line to separate encounters

# %%
create_encounter_table(cohort.similarity_encounters[:2])
# Out:
#           age gender ethnicity  \
# hadm_id
# 21764330   67      M     WHITE
# 24625361   41      M     WHITE
#
#                                                   diagnoses  \
# hadm_id
# 21764330  24290, 2724, 30500, 3051, 4019, 412, 41401, 42...
# 24625361  A400, A4102, B182, B1920, B950, B9562, D649, D...
#
#                                                   labevents  \
# hadm_id
# 21764330  50862: 3.2, 50868: 14.5, 50882: 26.25, 50893: ...
# 24625361  50802: 1.0, 50804: 26.0, 50813: 1.950000000000...
#
#                                                 inputevents  \
# hadm_id
# 21764330  220949, 222011, 222011, 225158, 225798, 226363...
# 24625361  220949, 220949, 220949, 220949, 220949, 220949...
#
#           heart_rate_vitalsigns  sbp_ni_vitalsigns  dbp_ni_vitalsigns  \
# hadm_id
# 21764330              48.750000            108.000          58.771429
# 24625361              71.666667            119.625          95.767442
#
#           mbp_ni_vitalsigns  resp_rate_vitalsigns  temperature_vitalsigns  \
# hadm_id
# 21764330           59.00000             19.514286               94.000000
# 24625361           81.02381             21.139535              115.095238
#
#           spo2_vitalsigns  glucose_vitalsigns
# hadm_id
# 21764330        98.371429           37.085000
# 24625361        96.093023           36.896667

# %%
display_encounter_similarities(cohort.similarity_encounters[:2])
# Out:
# Comparing encounter 21764330 with encounter 24625361:
# Age difference: 26 years
# Gender: M
# Ethnicity: WHITE
# No common diagnoses codes
# Common labevent item ids:
# Item 51476: 0.0
# Common inputevent item ids: 226452, 220949, 225158, 225798
# Common vitalsigns:
# dbp_ni: 22.91666666666667
# glucose: 11.625
# heart_rate: 36.99601328903654
# mbp_ni: 22.02380952380952
# resp_rate: 1.6252491694352145
# sbp_ni: 21.095238095238102
# spo2: 2.27840531561462
# temperature: 0.18833333333333258

# %%
sims = cohort.compare_encounters(scale_by_distribution=True, normalize_categories=False)
# Out:
# Finished encounter 21764330
# Finished encounter 24625361
# Finished encounter 27370800
# Finished encounter 20532621
# Finished encounter 27921263
# Finished encounter 22904714
# Finished encounter 25415625
# Finished encounter 25366699
# Finished encounter 21658149
# Finished encounter 25155096
# Finished encounter 22130791
# Finished encounter 20664607
# Finished encounter 29068519
# Finished encounter 26717744
# Finished encounter 24061120
# Finished encounter 29056733
# Finished encounter 24080968
# Finished encounter 28186950
# Finished encounter 21842619
# Finished encounter 27779433

# %%
sims
# Out:
# [{'encounter_a': 21764330,
#   'encounter_b': 21764330,
#   'similarity': {'demographics_sim': 1.0,
#    'diagnoses_sim': 1.0,
#    'labevents_sim': 1.0,
#    'vitalsigns_sim': 1.0,
#    'inputevents_sim': 1.0}},
#  {'encounter_a': 21764330,
#   'encounter_b': 24625361,
#   'similarity': {'demographics_sim': 0.8706467661691543,
#    'diagnoses_sim': 0.2977161225312944,
#    'labevents_sim': 0.16867670541402444,
#    'vitalsigns_sim': 0.08978839848911802,
#    'inputevents_sim': 0.2222222222222222}},
#  {'encounter_a': 21764330,
#   'encounter_b': 27370800,
#   'similarity': {'demographics_sim': 0.9857142857142858,
#    'diagnoses_sim': 0.4276505891172504,
#    'labevents_sim': 0.17749869785740813,
#    'vitalsigns_sim': 0.14817885867700778,
#    'inputevents_sim': 0.12195121951219512}},
#  {'encounter_a': 21764330,
#   'encounter_b': 20532621,
#   'similarity': {'demographics_sim': 0.8606965174129353,
#    'diagnoses_sim': 0.11297823627789069,
#    'labevents_sim': 0.21606636748839605,
#    'vitalsigns_sim': 0.06111897115211481,
#    'inputevents_sim': 0.17391304347826086}},
#  {'encounter_a': 21764330,
#   'encounter_b': 27921263,
#   'similarity': {'demographics_sim': 0.6056910569105691,
#    'diagnoses_sim': 0.6268334053422616,
#    'labevents_sim': 0.17247821858974854,
#    'vitalsigns_sim': 0.15362377586749487,
#    'inputevents_sim': 0.08571428571428572}},
#  {'encounter_a': 21764330,
#   'encounter_b': 22904714,
#   'similarity': {'demographics_sim': 0.9552238805970149,
#    'diagnoses_sim': 0.4391499589979007,
#    'labevents_sim': 0.1624558558046687,
#    'vitalsigns_sim': 0.21228149382817793,
#    'inputevents_sim': 0.46153846153846156}},
#  {'encounter_a': 21764330,
#   'encounter_b': 25415625,
#   'similarity': {'demographics_sim': 0.647887323943662,
#    'diagnoses_sim': 0.23245440187409822,
#    'labevents_sim': 0.1433499006098155,
#    'vitalsigns_sim': 0.14246394714039354,
#    'inputevents_sim': 0.2222222222222222}},
#  {'encounter_a': 21764330,
#   'encounter_b': 25366699,
#   'similarity': {'demographics_sim': 0.596078431372549,
#    'diagnoses_sim': 0.442233883337632,
#    'labevents_sim': 0.17624082349716966,
#    'vitalsigns_sim': 0.10358651658641968,
#    'inputevents_sim': 0.2727272727272727}},
#  {'encounter_a': 21764330,
#   'encounter_b': 21658149,
#   'similarity': {'demographics_sim': 0.3333333333333333,
#    'diagnoses_sim': 0.33389613611932173,
#    'labevents_sim': 0.14602746015691484,
#    'vitalsigns_sim': 0.2481275041223469,
#    'inputevents_sim': 0.125}},
#  {'encounter_a': 21764330,
#   'encounter_b': 25155096,
#   'similarity': {'demographics_sim': 0.582089552238806,
#    'diagnoses_sim': 0.6826838102547836,
#    'labevents_sim': 0.20915846240428207,
#    'vitalsigns_sim': 0.11367923490385438,
#    'inputevents_sim': 0.18181818181818182}},
#  {'encounter_a': 21764330,
#   'encounter_b': 22130791,
#   'similarity': {'demographics_sim': 0.9233716475095786,
#    'diagnoses_sim': 0.4147705245856238,
#    'labevents_sim': 0.1800988557115317,
#    'vitalsigns_sim': 0.21776694950948863,
#    'inputevents_sim': 0.2}},
#  {'encounter_a': 21764330,
#   'encounter_b': 20664607,
#   'similarity': {'demographics_sim': 0.32367149758454106,
#    'diagnoses_sim': 0.5242055865979296,
#    'labevents_sim': 0.23748762496224637,
#    'vitalsigns_sim': 0.1326139463376379,
#    'inputevents_sim': 0.4}},
#  {'encounter_a': 21764330,
#   'encounter_b': 29068519,
#   'similarity': {'demographics_sim': 0.29777777777777775,
#    'diagnoses_sim': 0.3271101826171991,
#    'labevents_sim': 0.19334620026761418,
#    'vitalsigns_sim': 0.16461141465466,
#    'inputevents_sim': 0.12903225806451613}},
#  {'encounter_a': 21764330,
#   'encounter_b': 26717744,
#   'similarity': {'demographics_sim': 0.9644444444444444,
#    'diagnoses_sim': 0.39532032706378123,
#    'labevents_sim': 0.1773226650297239,
#    'vitalsigns_sim': 0.4178553041103571,
#    'inputevents_sim': 0.20689655172413793}},
#  {'encounter_a': 21764330,
#   'encounter_b': 24061120,
#   'similarity': {'demographics_sim': 0.6523809523809524,
#    'diagnoses_sim': 0.09864806078909805,
#    'labevents_sim': 0.20018746802238307,
#    'vitalsigns_sim': 0.1700645214672971,
#    'inputevents_sim': 0.2857142857142857}},
#  {'encounter_a': 21764330,
#   'encounter_b': 29056733,
#   'similarity': {'demographics_sim': 0.293859649122807,
#    'diagnoses_sim': 0.3948703891653005,
#    'labevents_sim': 0.1684434530174754,
#    'vitalsigns_sim': 0.1773241977041476,
#    'inputevents_sim': 0.1388888888888889}},
#  {'encounter_a': 21764330,
#   'encounter_b': 24080968,
#   'similarity': {'demographics_sim': 0.3284313725490196,
#    'diagnoses_sim': 0.5245387643343788,
#    'labevents_sim': 0.18015756228427487,
#    'vitalsigns_sim': 0.2683622999293262,
#    'inputevents_sim': 0.1111111111111111}},
#  {'encounter_a': 21764330,
#   'encounter_b': 28186950,
#   'similarity': {'demographics_sim': 0.6567164179104478,
#    'diagnoses_sim': 0.5232683130372827,
#    'labevents_sim': 0.15786554111039894,
#    'vitalsigns_sim': 0.21303972087181927,
#    'inputevents_sim': 0.2}},
#  {'encounter_a': 21764330,
#   'encounter_b': 21842619,
#   'similarity': {'demographics_sim': 0.9950248756218906,
#    'diagnoses_sim': 0.5419579096593792,
#    'labevents_sim': 0.1661560516437127,
#    'vitalsigns_sim': 0.10840208807712698,
#    'inputevents_sim': 0.3333333333333333}},
#  {'encounter_a': 21764330,
#   'encounter_b': 27779433,
#   'similarity': {'demographics_sim': 0.572139303482587,
#    'diagnoses_sim': 0.39019037847858373,
#    'labevents_sim': 0.19403278549600939,
#    'vitalsigns_sim': 0.18766622203590672,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 24625361,
#   'encounter_b': 21764330,
#   'similarity': {'demographics_sim': 0.8706467661691543,
#    'diagnoses_sim': 0.2977161225312944,
#    'labevents_sim': 0.16867670541402444,
#    'vitalsigns_sim': 0.08978839848911802,
#    'inputevents_sim': 0.2222222222222222}},
#  {'encounter_a': 24625361,
#   'encounter_b': 24625361,
#   'similarity': {'demographics_sim': 1.0,
#    'diagnoses_sim': 1.0,
#    'labevents_sim': 1.0,
#    'vitalsigns_sim': 1.0,
#    'inputevents_sim': 1.0}},
#  {'encounter_a': 24625361,
#   'encounter_b': 27370800,
#   'similarity': {'demographics_sim': 0.861904761904762,
#    'diagnoses_sim': 0.4628979128550971,
#    'labevents_sim': 0.19847269432581188,
#    'vitalsigns_sim': 0.10371999155814923,
#    'inputevents_sim': 0.23809523809523808}},
#  {'encounter_a': 24625361,
#   'encounter_b': 20532621,
#   'similarity': {'demographics_sim': 0.983739837398374,
#    'diagnoses_sim': 0.13961525068987327,
#    'labevents_sim': 0.15488167364050612,
#    'vitalsigns_sim': 0.21817141536589188,
#    'inputevents_sim': 0.2222222222222222}},
#  {'encounter_a': 24625361,
#   'encounter_b': 27921263,
#   'similarity': {'demographics_sim': 0.5,
#    'diagnoses_sim': 0.22651121417252534,
#    'labevents_sim': 0.15210159229699652,
#    'vitalsigns_sim': 0.05563754355556793,
#    'inputevents_sim': 0.1891891891891892}},
#  {'encounter_a': 24625361,
#   'encounter_b': 22904714,
#   'similarity': {'demographics_sim': 0.9022988505747126,
#    'diagnoses_sim': 0.4408222417747799,
#    'labevents_sim': 0.1556962855988494,
#    'vitalsigns_sim': 0.12118897146030777,
#    'inputevents_sim': 0.3157894736842105}},
#  {'encounter_a': 24625361,
#   'encounter_b': 25415625,
#   'similarity': {'demographics_sim': 0.5258215962441315,
#    'diagnoses_sim': 0.39796147994142145,
#    'labevents_sim': 0.19201435004471523,
#    'vitalsigns_sim': 0.15833539296360097,
#    'inputevents_sim': 0.13333333333333333}},
#  {'encounter_a': 24625361,
#   'encounter_b': 25366699,
#   'similarity': {'demographics_sim': 0.49411764705882355,
#    'diagnoses_sim': 0.26230467026591425,
#    'labevents_sim': 0.12370532995568351,
#    'vitalsigns_sim': 0.18071799746853154,
#    'inputevents_sim': 0.1111111111111111}},
#  {'encounter_a': 24625361,
#   'encounter_b': 21658149,
#   'similarity': {'demographics_sim': 0.20398009950248755,
#    'diagnoses_sim': 0.5852371282521143,
#    'labevents_sim': 0.12293740295861737,
#    'vitalsigns_sim': 0.10386747066270917,
#    'inputevents_sim': 0.2222222222222222}},
#  {'encounter_a': 24625361,
#   'encounter_b': 25155096,
#   'similarity': {'demographics_sim': 0.6066666666666667,
#    'diagnoses_sim': 0.24480953661560548,
#    'labevents_sim': 0.1581298263703525,
#    'vitalsigns_sim': 0.16145055716648954,
#    'inputevents_sim': 0.11764705882352941}},
#  {'encounter_a': 24625361,
#   'encounter_b': 22130791,
#   'similarity': {'demographics_sim': 0.8237547892720306,
#    'diagnoses_sim': 0.47183831985812635,
#    'labevents_sim': 0.17043982508848496,
#    'vitalsigns_sim': 0.12670272196142693,
#    'inputevents_sim': 0.2727272727272727}},
#  {'encounter_a': 24625361,
#   'encounter_b': 20664607,
#   'similarity': {'demographics_sim': 0.19806763285024154,
#    'diagnoses_sim': 0.3127391868419364,
#    'labevents_sim': 0.16737944005959518,
#    'vitalsigns_sim': 0.19571864565770303,
#    'inputevents_sim': 0.1111111111111111}},
#  {'encounter_a': 24625361,
#   'encounter_b': 29068519,
#   'similarity': {'demographics_sim': 0.1822222222222222,
#    'diagnoses_sim': 0.5394615815573461,
#    'labevents_sim': 0.20255530923588502,
#    'vitalsigns_sim': 0.1711695749446516,
#    'inputevents_sim': 0.28125}},
#  {'encounter_a': 24625361,
#   'encounter_b': 26717744,
#   'similarity': {'demographics_sim': 0.8488888888888889,
#    'diagnoses_sim': 0.3179134769785759,
#    'labevents_sim': 0.13638070816887585,
#    'vitalsigns_sim': 0.11145706431522831,
#    'inputevents_sim': 0.3225806451612903}},
#  {'encounter_a': 24625361,
#   'encounter_b': 24061120,
#   'similarity': {'demographics_sim': 0.5285714285714286,
#    'diagnoses_sim': 0.3568443479891117,
#    'labevents_sim': 0.19584786736126444,
#    'vitalsigns_sim': 0.18089016618634196,
#    'inputevents_sim': 0.5}},
#  {'encounter_a': 24625361,
#   'encounter_b': 29056733,
#   'similarity': {'demographics_sim': 0.17982456140350878,
#    'diagnoses_sim': 0.45696329084075243,
#    'labevents_sim': 0.15742736821744538,
#    'vitalsigns_sim': 0.16203002842241873,
#    'inputevents_sim': 0.23684210526315788}},
#  {'encounter_a': 24625361,
#   'encounter_b': 24080968,
#   'similarity': {'demographics_sim': 0.20098039215686272,
#    'diagnoses_sim': 0.46891533488758286,
#    'labevents_sim': 0.19790595373646605,
#    'vitalsigns_sim': 0.10072046881506991,
#    'inputevents_sim': 0.06666666666666667}},
#  {'encounter_a': 24625361,
#   'encounter_b': 28186950,
#   'similarity': {'demographics_sim': 0.5435897435897435,
#    'diagnoses_sim': 0.4016419907425558,
#    'labevents_sim': 0.1807669225009611,
#    'vitalsigns_sim': 0.08372468281493337,
#    'inputevents_sim': 0.2413793103448276}},
#  {'encounter_a': 24625361,
#   'encounter_b': 21842619,
#   'similarity': {'demographics_sim': 0.8737373737373737,
#    'diagnoses_sim': 0.3619929246486977,
#    'labevents_sim': 0.12096806014318878,
#    'vitalsigns_sim': 0.13893663686983712,
#    'inputevents_sim': 0.29411764705882354}},
#  {'encounter_a': 24625361,
#   'encounter_b': 27779433,
#   'similarity': {'demographics_sim': 0.6180555555555556,
#    'diagnoses_sim': 0.10624441764329381,
#    'labevents_sim': 0.15266699955648969,
#    'vitalsigns_sim': 0.1706832458351286,
#    'inputevents_sim': 0.21428571428571427}},
#  {'encounter_a': 27370800,
#   'encounter_b': 21764330,
#   'similarity': {'demographics_sim': 0.9857142857142858,
#    'diagnoses_sim': 0.4276505891172504,
#    'labevents_sim': 0.17749869785740813,
#    'vitalsigns_sim': 0.14817885867700778,
#    'inputevents_sim': 0.12195121951219512}},
#  {'encounter_a': 27370800,
#   'encounter_b': 24625361,
#   'similarity': {'demographics_sim': 0.861904761904762,
#    'diagnoses_sim': 0.4628979128550971,
#    'labevents_sim': 0.19847269432581188,
#    'vitalsigns_sim': 0.10371999155814923,
#    'inputevents_sim': 0.23809523809523808}},
#  {'encounter_a': 27370800,
#   'encounter_b': 27370800,
#   'similarity': {'demographics_sim': 1.0,
#    'diagnoses_sim': 1.0,
#    'labevents_sim': 1.0,
#    'vitalsigns_sim': 1.0,
#    'inputevents_sim': 1.0}},
#  {'encounter_a': 27370800,
#   'encounter_b': 20532621,
#   'similarity': {'demographics_sim': 0.8523809523809524,
#    'diagnoses_sim': 0.09086466808559863,
#    'labevents_sim': 0.18351552322107556,
#    'vitalsigns_sim': 0.17768052644280735,
#    'inputevents_sim': 0.26666666666666666}},
#  {'encounter_a': 27370800,
#   'encounter_b': 27921263,
#   'similarity': {'demographics_sim': 0.6178861788617886,
#    'diagnoses_sim': 0.4448872318632171,
#    'labevents_sim': 0.1731519229685977,
#    'vitalsigns_sim': 0.150924621410811,
#    'inputevents_sim': 0.3333333333333333}},
#  {'encounter_a': 27370800,
#   'encounter_b': 22904714,
#   'similarity': {'demographics_sim': 0.9428571428571428,
#    'diagnoses_sim': 0.5270628790586652,
#    'labevents_sim': 0.19446418915845376,
#    'vitalsigns_sim': 0.13356684643930206,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 27370800,
#   'encounter_b': 25415625,
#   'similarity': {'demographics_sim': 0.6619718309859155,
#    'diagnoses_sim': 0.41854672203071175,
#    'labevents_sim': 0.22697784564861492,
#    'vitalsigns_sim': 0.16366562630898937,
#    'inputevents_sim': 0.05128205128205128}},
#  {'encounter_a': 27370800,
#   'encounter_b': 25366699,
#   'similarity': {'demographics_sim': 0.6078431372549019,
#    'diagnoses_sim': 0.3642501948261938,
#    'labevents_sim': 0.14289439805234352,
#    'vitalsigns_sim': 0.20400791287123773,
#    'inputevents_sim': 0.07317073170731707}},
#  {'encounter_a': 27370800,
#   'encounter_b': 21658149,
#   'similarity': {'demographics_sim': 0.3190476190476191,
#    'diagnoses_sim': 0.457445342339136,
#    'labevents_sim': 0.1172008781366669,
#    'vitalsigns_sim': 0.06562643446123123,
#    'inputevents_sim': 0.26666666666666666}},
#  {'encounter_a': 27370800,
#   'encounter_b': 25155096,
#   'similarity': {'demographics_sim': 0.5714285714285714,
#    'diagnoses_sim': 0.3560117229129744,
#    'labevents_sim': 0.14578855960646928,
#    'vitalsigns_sim': 0.1327608733811433,
#    'inputevents_sim': 0.023809523809523808}},
#  {'encounter_a': 27370800,
#   'encounter_b': 22130791,
#   'similarity': {'demographics_sim': 0.9348659003831418,
#    'diagnoses_sim': 0.5880419891796439,
#    'labevents_sim': 0.15788517244719397,
#    'vitalsigns_sim': 0.11236659981194676,
#    'inputevents_sim': 0.40425531914893614}},
#  {'encounter_a': 27370800,
#   'encounter_b': 20664607,
#   'similarity': {'demographics_sim': 0.32857142857142857,
#    'diagnoses_sim': 0.4063914339289218,
#    'labevents_sim': 0.18034368616423496,
#    'vitalsigns_sim': 0.15467766115691464,
#    'inputevents_sim': 0.1282051282051282}},
#  {'encounter_a': 27370800,
#   'encounter_b': 29068519,
#   'similarity': {'demographics_sim': 0.3111111111111111,
#    'diagnoses_sim': 0.5277067848295682,
#    'labevents_sim': 0.19184723900452222,
#    'vitalsigns_sim': 0.14429775136362738,
#    'inputevents_sim': 0.32653061224489793}},
#  {'encounter_a': 27370800,
#   'encounter_b': 26717744,
#   'similarity': {'demographics_sim': 0.9777777777777777,
#    'diagnoses_sim': 0.40590708145012677,
#    'labevents_sim': 0.1882641337428194,
#    'vitalsigns_sim': 0.15374171197920744,
#    'inputevents_sim': 0.4772727272727273}},
#  {'encounter_a': 27370800,
#   'encounter_b': 24061120,
#   'similarity': {'demographics_sim': 0.6666666666666666,
#    'diagnoses_sim': 0.46172758837177846,
#    'labevents_sim': 0.1706362128103688,
#    'vitalsigns_sim': 0.11467282721820107,
#    'inputevents_sim': 0.35714285714285715}},
#  {'encounter_a': 27370800,
#   'encounter_b': 29056733,
#   'similarity': {'demographics_sim': 0.30701754385964913,
#    'diagnoses_sim': 0.38740429289309497,
#    'labevents_sim': 0.18546209238127526,
#    'vitalsigns_sim': 0.20861470932266726,
#    'inputevents_sim': 0.5106382978723404}},
#  {'encounter_a': 27370800,
#   'encounter_b': 24080968,
#   'similarity': {'demographics_sim': 0.3238095238095238,
#    'diagnoses_sim': 0.5170757250613577,
#    'labevents_sim': 0.2338847033776354,
#    'vitalsigns_sim': 0.14907661028650004,
#    'inputevents_sim': 0.02564102564102564}},
#  {'encounter_a': 27370800,
#   'encounter_b': 28186950,
#   'similarity': {'demographics_sim': 0.6428571428571429,
#    'diagnoses_sim': 0.47343173158714763,
#    'labevents_sim': 0.1765725350962734,
#    'vitalsigns_sim': 0.14155180467406708,
#    'inputevents_sim': 0.3333333333333333}},
#  {'encounter_a': 27370800,
#   'encounter_b': 21842619,
#   'similarity': {'demographics_sim': 0.9809523809523809,
#    'diagnoses_sim': 0.4401371386573613,
#    'labevents_sim': 0.13323764291800952,
#    'vitalsigns_sim': 0.0789871698762086,
#    'inputevents_sim': 0.09523809523809523}},
#  {'encounter_a': 27370800,
#   'encounter_b': 27779433,
#   'similarity': {'demographics_sim': 0.5619047619047619,
#    'diagnoses_sim': 0.22828980320431277,
#    'labevents_sim': 0.15067741001780013,
#    'vitalsigns_sim': 0.2303127887514618,
#    'inputevents_sim': 0.3181818181818182}},
#  {'encounter_a': 20532621,
#   'encounter_b': 21764330,
#   'similarity': {'demographics_sim': 0.8606965174129353,
#    'diagnoses_sim': 0.11297823627789069,
#    'labevents_sim': 0.21606636748839605,
#    'vitalsigns_sim': 0.06111897115211481,
#    'inputevents_sim': 0.17391304347826086}},
#  {'encounter_a': 20532621,
#   'encounter_b': 24625361,
#   'similarity': {'demographics_sim': 0.983739837398374,
#    'diagnoses_sim': 0.13961525068987327,
#    'labevents_sim': 0.15488167364050612,
#    'vitalsigns_sim': 0.21817141536589188,
#    'inputevents_sim': 0.2222222222222222}},
#  {'encounter_a': 20532621,
#   'encounter_b': 27370800,
#   'similarity': {'demographics_sim': 0.8523809523809524,
#    'diagnoses_sim': 0.09086466808559863,
#    'labevents_sim': 0.18351552322107556,
#    'vitalsigns_sim': 0.17768052644280735,
#    'inputevents_sim': 0.26666666666666666}},
#  {'encounter_a': 20532621,
#   'encounter_b': 20532621,
#   'similarity': {'demographics_sim': 1.0,
#    'diagnoses_sim': 1.0,
#    'labevents_sim': 1.0,
#    'vitalsigns_sim': 1.0,
#    'inputevents_sim': 1.0}},
#  {'encounter_a': 20532621,
#   'encounter_b': 27921263,
#   'similarity': {'demographics_sim': 0.491869918699187,
#    'diagnoses_sim': 0.0,
#    'labevents_sim': 0.17266804859442111,
#    'vitalsigns_sim': 0.1281083293663175,
#    'inputevents_sim': 0.2894736842105263}},
#  {'encounter_a': 20532621,
#   'encounter_b': 22904714,
#   'similarity': {'demographics_sim': 0.8908045977011494,
#    'diagnoses_sim': 0.20685659724562283,
#    'labevents_sim': 0.18054043885118246,
#    'vitalsigns_sim': 0.1284261081912738,
#    'inputevents_sim': 0.2}},
#  {'encounter_a': 20532621,
#   'encounter_b': 25415625,
#   'similarity': {'demographics_sim': 0.5164319248826291,
#    'diagnoses_sim': 0.12624327390032136,
#    'labevents_sim': 0.14744524992192254,
#    'vitalsigns_sim': 0.25899037026290206,
#    'inputevents_sim': 0.15789473684210525}},
#  {'encounter_a': 20532621,
#   'encounter_b': 25366699,
#   'similarity': {'demographics_sim': 0.48627450980392156,
#    'diagnoses_sim': 0.06926345256223768,
#    'labevents_sim': 0.2069465754308055,
#    'vitalsigns_sim': 0.318934706679758,
#    'inputevents_sim': 0.13636363636363635}},
#  {'encounter_a': 20532621,
#   'encounter_b': 21658149,
#   'similarity': {'demographics_sim': 0.19402985074626866,
#    'diagnoses_sim': 0.24295172120159414,
#    'labevents_sim': 0.1656587825103582,
#    'vitalsigns_sim': 0.07275897518665862,
#    'inputevents_sim': 0.08571428571428572}},
#  {'encounter_a': 20532621,
#   'encounter_b': 25155096,
#   'similarity': {'demographics_sim': 0.5933333333333334,
#    'diagnoses_sim': 0.09294322956706916,
#    'labevents_sim': 0.18490922883166064,
#    'vitalsigns_sim': 0.1767037025383793,
#    'inputevents_sim': 0.09090909090909091}},
#  {'encounter_a': 20532621,
#   'encounter_b': 22130791,
#   'similarity': {'demographics_sim': 0.8160919540229885,
#    'diagnoses_sim': 0.10037884171263589,
#    'labevents_sim': 0.17397598460588984,
#    'vitalsigns_sim': 0.14498473422145108,
#    'inputevents_sim': 0.23684210526315788}},
#  {'encounter_a': 20532621,
#   'encounter_b': 20664607,
#   'similarity': {'demographics_sim': 0.18840579710144925,
#    'diagnoses_sim': 0.16171896710344916,
#    'labevents_sim': 0.2057383534174199,
#    'vitalsigns_sim': 0.24104971772526007,
#    'inputevents_sim': 0.13636363636363635}},
#  {'encounter_a': 20532621,
#   'encounter_b': 29068519,
#   'similarity': {'demographics_sim': 0.17333333333333334,
#    'diagnoses_sim': 0.10286959226182524,
#    'labevents_sim': 0.13758444501318012,
#    'vitalsigns_sim': 0.15867209402423724,
#    'inputevents_sim': 0.21052631578947367}},
#  {'encounter_a': 20532621,
#   'encounter_b': 26717744,
#   'similarity': {'demographics_sim': 0.84,
#    'diagnoses_sim': 0.10829271524712124,
#    'labevents_sim': 0.13441733891679641,
#    'vitalsigns_sim': 0.07619626422120473,
#    'inputevents_sim': 0.35294117647058826}},
#  {'encounter_a': 20532621,
#   'encounter_b': 24061120,
#   'similarity': {'demographics_sim': 0.5190476190476191,
#    'diagnoses_sim': 0.0864921207033808,
#    'labevents_sim': 0.199711045623172,
#    'vitalsigns_sim': 0.17122495058606377,
#    'inputevents_sim': 0.22580645161290322}},
#  {'encounter_a': 20532621,
#   'encounter_b': 29056733,
#   'similarity': {'demographics_sim': 0.17105263157894737,
#    'diagnoses_sim': 0.1993724074827464,
#    'labevents_sim': 0.17793410061797643,
#    'vitalsigns_sim': 0.2289763010117101,
#    'inputevents_sim': 0.23809523809523808}},
#  {'encounter_a': 20532621,
#   'encounter_b': 24080968,
#   'similarity': {'demographics_sim': 0.19117647058823528,
#    'diagnoses_sim': 0.17190426026497857,
#    'labevents_sim': 0.19371905963829392,
#    'vitalsigns_sim': 0.13911896774748506,
#    'inputevents_sim': 0.05}},
#  {'encounter_a': 20532621,
#   'encounter_b': 28186950,
#   'similarity': {'demographics_sim': 0.5333333333333333,
#    'diagnoses_sim': 0.14306258499267258,
#    'labevents_sim': 0.13635488470551554,
#    'vitalsigns_sim': 0.08566653380153234,
#    'inputevents_sim': 0.20588235294117646}},
#  {'encounter_a': 20532621,
#   'encounter_b': 21842619,
#   'similarity': {'demographics_sim': 0.8636363636363636,
#    'diagnoses_sim': 0.08888351672291628,
#    'labevents_sim': 0.10832054365068954,
#    'vitalsigns_sim': 0.13458111314211077,
#    'inputevents_sim': 0.125}},
#  {'encounter_a': 20532621,
#   'encounter_b': 27779433,
#   'similarity': {'demographics_sim': 0.6041666666666666,
#    'diagnoses_sim': 0.11694028387190389,
#    'labevents_sim': 0.1318558701433919,
#    'vitalsigns_sim': 0.21823827844322366,
#    'inputevents_sim': 0.3}},
#  {'encounter_a': 27921263,
#   'encounter_b': 21764330,
#   'similarity': {'demographics_sim': 0.6056910569105691,
#    'diagnoses_sim': 0.6268334053422616,
#    'labevents_sim': 0.17247821858974854,
#    'vitalsigns_sim': 0.15362377586749487,
#    'inputevents_sim': 0.08571428571428572}},
#  {'encounter_a': 27921263,
#   'encounter_b': 24625361,
#   'similarity': {'demographics_sim': 0.5,
#    'diagnoses_sim': 0.22651121417252534,
#    'labevents_sim': 0.15210159229699652,
#    'vitalsigns_sim': 0.05563754355556793,
#    'inputevents_sim': 0.1891891891891892}},
#  {'encounter_a': 27921263,
#   'encounter_b': 27370800,
#   'similarity': {'demographics_sim': 0.6178861788617886,
#    'diagnoses_sim': 0.4448872318632171,
#    'labevents_sim': 0.1731519229685977,
#    'vitalsigns_sim': 0.150924621410811,
#    'inputevents_sim': 0.3333333333333333}},
#  {'encounter_a': 27921263,
#   'encounter_b': 20532621,
#   'similarity': {'demographics_sim': 0.491869918699187,
#    'diagnoses_sim': 0.0,
#    'labevents_sim': 0.17266804859442111,
#    'vitalsigns_sim': 0.1281083293663175,
#    'inputevents_sim': 0.2894736842105263}},
#  {'encounter_a': 27921263,
#   'encounter_b': 27921263,
#   'similarity': {'demographics_sim': 1.0,
#    'diagnoses_sim': 1.0,
#    'labevents_sim': 1.0,
#    'vitalsigns_sim': 1.0,
#    'inputevents_sim': 1.0}},
#  {'encounter_a': 27921263,
#   'encounter_b': 22904714,
#   'similarity': {'demographics_sim': 0.5691056910569106,
#    'diagnoses_sim': 0.3831306105404002,
#    'labevents_sim': 0.1798442106785641,
#    'vitalsigns_sim': 0.1605763992763541,
#    'inputevents_sim': 0.1388888888888889}},
#  {'encounter_a': 27921263,
#   'encounter_b': 25415625,
#   'similarity': {'demographics_sim': 0.2886178861788618,
#    'diagnoses_sim': 0.309441536933653,
#    'labevents_sim': 0.14427768049550882,
#    'vitalsigns_sim': 0.20678736625012564,
#    'inputevents_sim': 0.1}},
#  {'encounter_a': 27921263,
#   'encounter_b': 25366699,
#   'similarity': {'demographics_sim': 0.3215686274509804,
#    'diagnoses_sim': 0.4930425867530345,
#    'labevents_sim': 0.1828743797723644,
#    'vitalsigns_sim': 0.17279557311321173,
#    'inputevents_sim': 0.09090909090909091}},
#  {'encounter_a': 27921263,
#   'encounter_b': 21658149,
#   'similarity': {'demographics_sim': 0.6056910569105691,
#    'diagnoses_sim': 0.28956421072880806,
#    'labevents_sim': 0.1070390536509527,
#    'vitalsigns_sim': 0.09124224514469209,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 27921263,
#   'encounter_b': 25155096,
#   'similarity': {'demographics_sim': 0.2032520325203252,
#    'diagnoses_sim': 0.604626910034047,
#    'labevents_sim': 0.14988394044345205,
#    'vitalsigns_sim': 0.13359175463982972,
#    'inputevents_sim': 0.06060606060606061}},
#  {'encounter_a': 27921263,
#   'encounter_b': 22130791,
#   'similarity': {'demographics_sim': 0.6475095785440613,
#    'diagnoses_sim': 0.4987560914311465,
#    'labevents_sim': 0.18139867854514413,
#    'vitalsigns_sim': 0.14727575775451923,
#    'inputevents_sim': 0.2608695652173913}},
#  {'encounter_a': 27921263,
#   'encounter_b': 20664607,
#   'similarity': {'demographics_sim': 0.6138211382113821,
#    'diagnoses_sim': 0.33369970798891724,
#    'labevents_sim': 0.14851807017144653,
#    'vitalsigns_sim': 0.10823526017896476,
#    'inputevents_sim': 0.125}},
#  {'encounter_a': 27921263,
#   'encounter_b': 29068519,
#   'similarity': {'demographics_sim': 0.6382113821138211,
#    'diagnoses_sim': 0.309730109583707,
#    'labevents_sim': 0.16236601806185308,
#    'vitalsigns_sim': 0.1478448429495833,
#    'inputevents_sim': 0.1875}},
#  {'encounter_a': 27921263,
#   'encounter_b': 26717744,
#   'similarity': {'demographics_sim': 0.6382113821138211,
#    'diagnoses_sim': 0.45294984192875865,
#    'labevents_sim': 0.1289938393620989,
#    'vitalsigns_sim': 0.18372578850190027,
#    'inputevents_sim': 0.32558139534883723}},
#  {'encounter_a': 27921263,
#   'encounter_b': 24061120,
#   'similarity': {'demographics_sim': 0.9512195121951219,
#    'diagnoses_sim': 0.15777480107351655,
#    'labevents_sim': 0.16040426555599235,
#    'vitalsigns_sim': 0.09774923720091541,
#    'inputevents_sim': 0.1951219512195122}},
#  {'encounter_a': 27921263,
#   'encounter_b': 29056733,
#   'similarity': {'demographics_sim': 0.6422764227642277,
#    'diagnoses_sim': 0.20200986170085103,
#    'labevents_sim': 0.12592197763880525,
#    'vitalsigns_sim': 0.20008044432388702,
#    'inputevents_sim': 0.2857142857142857}},
#  {'encounter_a': 27921263,
#   'encounter_b': 24080968,
#   'similarity': {'demographics_sim': 0.6097560975609756,
#    'diagnoses_sim': 0.6032752122133994,
#    'labevents_sim': 0.189340821393981,
#    'vitalsigns_sim': 0.1844162523627516,
#    'inputevents_sim': 0.06666666666666667}},
#  {'encounter_a': 27921263,
#   'encounter_b': 28186950,
#   'similarity': {'demographics_sim': 0.9308943089430894,
#    'diagnoses_sim': 0.4324512714749733,
#    'labevents_sim': 0.15754150625911623,
#    'vitalsigns_sim': 0.17995193046341468,
#    'inputevents_sim': 0.23809523809523808}},
#  {'encounter_a': 27921263,
#   'encounter_b': 21842619,
#   'similarity': {'demographics_sim': 0.6016260162601627,
#    'diagnoses_sim': 0.5111357962993197,
#    'labevents_sim': 0.14744124687442103,
#    'vitalsigns_sim': 0.09396438164013557,
#    'inputevents_sim': 0.08571428571428572}},
#  {'encounter_a': 27921263,
#   'encounter_b': 27779433,
#   'similarity': {'demographics_sim': 0.8617886178861789,
#    'diagnoses_sim': 0.3979742137107943,
#    'labevents_sim': 0.0737567768884539,
#    'vitalsigns_sim': 0.19691844982259815,
#    'inputevents_sim': 0.28205128205128205}},
#  {'encounter_a': 22904714,
#   'encounter_b': 21764330,
#   'similarity': {'demographics_sim': 0.9552238805970149,
#    'diagnoses_sim': 0.4391499589979007,
#    'labevents_sim': 0.1624558558046687,
#    'vitalsigns_sim': 0.21228149382817793,
#    'inputevents_sim': 0.46153846153846156}},
#  {'encounter_a': 22904714,
#   'encounter_b': 24625361,
#   'similarity': {'demographics_sim': 0.9022988505747126,
#    'diagnoses_sim': 0.4408222417747799,
#    'labevents_sim': 0.1556962855988494,
#    'vitalsigns_sim': 0.12118897146030777,
#    'inputevents_sim': 0.3157894736842105}},
#  {'encounter_a': 22904714,
#   'encounter_b': 27370800,
#   'similarity': {'demographics_sim': 0.9428571428571428,
#    'diagnoses_sim': 0.5270628790586652,
#    'labevents_sim': 0.19446418915845376,
#    'vitalsigns_sim': 0.13356684643930206,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 22904714,
#   'encounter_b': 20532621,
#   'similarity': {'demographics_sim': 0.8908045977011494,
#    'diagnoses_sim': 0.20685659724562283,
#    'labevents_sim': 0.18054043885118246,
#    'vitalsigns_sim': 0.1284261081912738,
#    'inputevents_sim': 0.2}},
#  {'encounter_a': 22904714,
#   'encounter_b': 27921263,
#   'similarity': {'demographics_sim': 0.5691056910569106,
#    'diagnoses_sim': 0.3831306105404002,
#    'labevents_sim': 0.1798442106785641,
#    'vitalsigns_sim': 0.1605763992763541,
#    'inputevents_sim': 0.1388888888888889}},
#  {'encounter_a': 22904714,
#   'encounter_b': 22904714,
#   'similarity': {'demographics_sim': 1.0,
#    'diagnoses_sim': 1.0,
#    'labevents_sim': 1.0,
#    'vitalsigns_sim': 1.0,
#    'inputevents_sim': 1.0}},
#  {'encounter_a': 22904714,
#   'encounter_b': 25415625,
#   'similarity': {'demographics_sim': 0.6056338028169014,
#    'diagnoses_sim': 0.31315716825458123,
#    'labevents_sim': 0.1434310640514057,
#    'vitalsigns_sim': 0.15483054586290151,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 22904714,
#   'encounter_b': 25366699,
#   'similarity': {'demographics_sim': 0.5607843137254902,
#    'diagnoses_sim': 0.36584273246193916,
#    'labevents_sim': 0.13998567269105908,
#    'vitalsigns_sim': 0.1825463733992083,
#    'inputevents_sim': 0.3076923076923077}},
#  {'encounter_a': 22904714,
#   'encounter_b': 21658149,
#   'similarity': {'demographics_sim': 0.2885572139303482,
#    'diagnoses_sim': 0.4600952175002424,
#    'labevents_sim': 0.10721952432692335,
#    'vitalsigns_sim': 0.11965763088267727,
#    'inputevents_sim': 0.25}},
#  {'encounter_a': 22904714,
#   'encounter_b': 25155096,
#   'similarity': {'demographics_sim': 0.6206896551724138,
#    'diagnoses_sim': 0.35132559834869337,
#    'labevents_sim': 0.18431824419294354,
#    'vitalsigns_sim': 0.12135842658870562,
#    'inputevents_sim': 0.06666666666666667}},
#  {'encounter_a': 22904714,
#   'encounter_b': 22130791,
#   'similarity': {'demographics_sim': 0.8888888888888888,
#    'diagnoses_sim': 0.46706645845006833,
#    'labevents_sim': 0.15412114572195906,
#    'vitalsigns_sim': 0.10527738760864841,
#    'inputevents_sim': 0.25806451612903225}},
#  {'encounter_a': 22904714,
#   'encounter_b': 20664607,
#   'similarity': {'demographics_sim': 0.2801932367149758,
#    'diagnoses_sim': 0.36911101536071106,
#    'labevents_sim': 0.15482303662050254,
#    'vitalsigns_sim': 0.13552893237338812,
#    'inputevents_sim': 0.3076923076923077}},
#  {'encounter_a': 22904714,
#   'encounter_b': 29068519,
#   'similarity': {'demographics_sim': 0.2577777777777778,
#    'diagnoses_sim': 0.4789933079336992,
#    'labevents_sim': 0.17080679056897474,
#    'vitalsigns_sim': 0.16782060605689586,
#    'inputevents_sim': 0.1875}},
#  {'encounter_a': 22904714,
#   'encounter_b': 26717744,
#   'similarity': {'demographics_sim': 0.9244444444444444,
#    'diagnoses_sim': 0.3756275251514626,
#    'labevents_sim': 0.12123404866779293,
#    'vitalsigns_sim': 0.24670729940075586,
#    'inputevents_sim': 0.22580645161290322}},
#  {'encounter_a': 22904714,
#   'encounter_b': 24061120,
#   'similarity': {'demographics_sim': 0.6095238095238096,
#    'diagnoses_sim': 0.346327497533916,
#    'labevents_sim': 0.15626764445999636,
#    'vitalsigns_sim': 0.1488116598278241,
#    'inputevents_sim': 0.30434782608695654}},
#  {'encounter_a': 22904714,
#   'encounter_b': 29056733,
#   'similarity': {'demographics_sim': 0.2543859649122807,
#    'diagnoses_sim': 0.46909897700131753,
#    'labevents_sim': 0.1629834932344014,
#    'vitalsigns_sim': 0.1545590010447625,
#    'inputevents_sim': 0.15789473684210525}},
#  {'encounter_a': 22904714,
#   'encounter_b': 24080968,
#   'similarity': {'demographics_sim': 0.28431372549019607,
#    'diagnoses_sim': 0.5527519779766056,
#    'labevents_sim': 0.16268915499638606,
#    'vitalsigns_sim': 0.16850411630043632,
#    'inputevents_sim': 0.08333333333333333}},
#  {'encounter_a': 22904714,
#   'encounter_b': 28186950,
#   'similarity': {'demographics_sim': 0.6307692307692307,
#    'diagnoses_sim': 0.5931881243486057,
#    'labevents_sim': 0.1270037366696663,
#    'vitalsigns_sim': 0.13111037157593644,
#    'inputevents_sim': 0.17857142857142858}},
#  {'encounter_a': 22904714,
#   'encounter_b': 21842619,
#   'similarity': {'demographics_sim': 0.9595959595959596,
#    'diagnoses_sim': 0.47361516329677555,
#    'labevents_sim': 0.11615298082210454,
#    'vitalsigns_sim': 0.2063315322610879,
#    'inputevents_sim': 0.35714285714285715}},
#  {'encounter_a': 22904714,
#   'encounter_b': 27779433,
#   'similarity': {'demographics_sim': 0.6091954022988506,
#    'diagnoses_sim': 0.22620580070171434,
#    'labevents_sim': 0.14019508589878288,
#    'vitalsigns_sim': 0.14632857330424762,
#    'inputevents_sim': 0.19230769230769232}},
#  {'encounter_a': 25415625,
#   'encounter_b': 21764330,
#   'similarity': {'demographics_sim': 0.647887323943662,
#    'diagnoses_sim': 0.23245440187409822,
#    'labevents_sim': 0.1433499006098155,
#    'vitalsigns_sim': 0.14246394714039354,
#    'inputevents_sim': 0.2222222222222222}},
#  {'encounter_a': 25415625,
#   'encounter_b': 24625361,
#   'similarity': {'demographics_sim': 0.5258215962441315,
#    'diagnoses_sim': 0.39796147994142145,
#    'labevents_sim': 0.19201435004471523,
#    'vitalsigns_sim': 0.15833539296360097,
#    'inputevents_sim': 0.13333333333333333}},
#  {'encounter_a': 25415625,
#   'encounter_b': 27370800,
#   'similarity': {'demographics_sim': 0.6619718309859155,
#    'diagnoses_sim': 0.41854672203071175,
#    'labevents_sim': 0.22697784564861492,
#    'vitalsigns_sim': 0.16366562630898937,
#    'inputevents_sim': 0.05128205128205128}},
#  {'encounter_a': 25415625,
#   'encounter_b': 20532621,
#   'similarity': {'demographics_sim': 0.5164319248826291,
#    'diagnoses_sim': 0.12624327390032136,
#    'labevents_sim': 0.14744524992192254,
#    'vitalsigns_sim': 0.25899037026290206,
#    'inputevents_sim': 0.15789473684210525}},
#  {'encounter_a': 25415625,
#   'encounter_b': 27921263,
#   'similarity': {'demographics_sim': 0.2886178861788618,
#    'diagnoses_sim': 0.309441536933653,
#    'labevents_sim': 0.14427768049550882,
#    'vitalsigns_sim': 0.20678736625012564,
#    'inputevents_sim': 0.1}},
#  {'encounter_a': 25415625,
#   'encounter_b': 22904714,
#   'similarity': {'demographics_sim': 0.6056338028169014,
#    'diagnoses_sim': 0.31315716825458123,
#    'labevents_sim': 0.1434310640514057,
#    'vitalsigns_sim': 0.15483054586290151,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 25415625,
#   'encounter_b': 25415625,
#   'similarity': {'demographics_sim': 1.0,
#    'diagnoses_sim': 1.0,
#    'labevents_sim': 1.0,
#    'vitalsigns_sim': 1.0,
#    'inputevents_sim': 1.0}},
#  {'encounter_a': 25415625,
#   'encounter_b': 25366699,
#   'similarity': {'demographics_sim': 0.611764705882353,
#    'diagnoses_sim': 0.3456450468816685,
#    'labevents_sim': 0.12709060729106286,
#    'vitalsigns_sim': 0.30196719171406544,
#    'inputevents_sim': 0.2857142857142857}},
#  {'encounter_a': 25415625,
#   'encounter_b': 21658149,
#   'similarity': {'demographics_sim': 0.3145539906103286,
#    'diagnoses_sim': 0.45071973899691675,
#    'labevents_sim': 0.11054931421387615,
#    'vitalsigns_sim': 0.03601870873960946,
#    'inputevents_sim': 0.047619047619047616}},
#  {'encounter_a': 25415625,
#   'encounter_b': 25155096,
#   'similarity': {'demographics_sim': 0.568075117370892,
#    'diagnoses_sim': 0.13870726796331195,
#    'labevents_sim': 0.110991100223941,
#    'vitalsigns_sim': 0.1866748274113767,
#    'inputevents_sim': 0.14285714285714285}},
#  {'encounter_a': 25415625,
#   'encounter_b': 22130791,
#   'similarity': {'demographics_sim': 0.6053639846743295,
#    'diagnoses_sim': 0.49624545694722083,
#    'labevents_sim': 0.16071851505417706,
#    'vitalsigns_sim': 0.06318593992010034,
#    'inputevents_sim': 0.10714285714285714}},
#  {'encounter_a': 25415625,
#   'encounter_b': 20664607,
#   'similarity': {'demographics_sim': 0.6572769953051644,
#    'diagnoses_sim': 0.12068635021123038,
#    'labevents_sim': 0.13582138043623496,
#    'vitalsigns_sim': 0.17402155010133635,
#    'inputevents_sim': 0.125}},
#  {'encounter_a': 25415625,
#   'encounter_b': 29068519,
#   'similarity': {'demographics_sim': 0.6488888888888888,
#    'diagnoses_sim': 0.5047582421047251,
#    'labevents_sim': 0.17931392126699794,
#    'vitalsigns_sim': 0.11139534229703052,
#    'inputevents_sim': 0.07142857142857142}},
#  {'encounter_a': 25415625,
#   'encounter_b': 26717744,
#   'similarity': {'demographics_sim': 0.6488888888888888,
#    'diagnoses_sim': 0.4541036582484851,
#    'labevents_sim': 0.19076782086400093,
#    'vitalsigns_sim': 0.1696040641421905,
#    'inputevents_sim': 0.1111111111111111}},
#  {'encounter_a': 25415625,
#   'encounter_b': 24061120,
#   'similarity': {'demographics_sim': 0.3286384976525822,
#    'diagnoses_sim': 0.4720991246925043,
#    'labevents_sim': 0.14104874491441866,
#    'vitalsigns_sim': 0.1149539007938135,
#    'inputevents_sim': 0.1}},
#  {'encounter_a': 25415625,
#   'encounter_b': 29056733,
#   'similarity': {'demographics_sim': 0.31140350877192985,
#    'diagnoses_sim': 0.26460261710187083,
#    'labevents_sim': 0.1646303211198853,
#    'vitalsigns_sim': 0.24929799849985398,
#    'inputevents_sim': 0.058823529411764705}},
#  {'encounter_a': 25415625,
#   'encounter_b': 24080968,
#   'similarity': {'demographics_sim': 0.3192488262910798,
#    'diagnoses_sim': 0.46463086019244665,
#    'labevents_sim': 0.20644785138829613,
#    'vitalsigns_sim': 0.22912628736336646,
#    'inputevents_sim': 0.25}},
#  {'encounter_a': 25415625,
#   'encounter_b': 28186950,
#   'similarity': {'demographics_sim': 0.3051643192488263,
#    'diagnoses_sim': 0.2773511206593506,
#    'labevents_sim': 0.16711310153668002,
#    'vitalsigns_sim': 0.12302633391200893,
#    'inputevents_sim': 0.13636363636363635}},
#  {'encounter_a': 25415625,
#   'encounter_b': 21842619,
#   'similarity': {'demographics_sim': 0.6431924882629108,
#    'diagnoses_sim': 0.31925279509432436,
#    'labevents_sim': 0.12916504143382457,
#    'vitalsigns_sim': 0.1470776305707149,
#    'inputevents_sim': 0.2222222222222222}},
#  {'encounter_a': 25415625,
#   'encounter_b': 27779433,
#   'similarity': {'demographics_sim': 0.22535211267605634,
#    'diagnoses_sim': 0.21654365366253975,
#    'labevents_sim': 0.1265112898357555,
#    'vitalsigns_sim': 0.21965760048878286,
#    'inputevents_sim': 0.045454545454545456}},
#  {'encounter_a': 25366699,
#   'encounter_b': 21764330,
#   'similarity': {'demographics_sim': 0.596078431372549,
#    'diagnoses_sim': 0.442233883337632,
#    'labevents_sim': 0.17624082349716966,
#    'vitalsigns_sim': 0.10358651658641968,
#    'inputevents_sim': 0.2727272727272727}},
#  {'encounter_a': 25366699,
#   'encounter_b': 24625361,
#   'similarity': {'demographics_sim': 0.49411764705882355,
#    'diagnoses_sim': 0.26230467026591425,
#    'labevents_sim': 0.12370532995568351,
#    'vitalsigns_sim': 0.18071799746853154,
#    'inputevents_sim': 0.1111111111111111}},
#  {'encounter_a': 25366699,
#   'encounter_b': 27370800,
#   'similarity': {'demographics_sim': 0.6078431372549019,
#    'diagnoses_sim': 0.3642501948261938,
#    'labevents_sim': 0.14289439805234352,
#    'vitalsigns_sim': 0.20400791287123773,
#    'inputevents_sim': 0.07317073170731707}},
#  {'encounter_a': 25366699,
#   'encounter_b': 20532621,
#   'similarity': {'demographics_sim': 0.48627450980392156,
#    'diagnoses_sim': 0.06926345256223768,
#    'labevents_sim': 0.2069465754308055,
#    'vitalsigns_sim': 0.318934706679758,
#    'inputevents_sim': 0.13636363636363635}},
#  {'encounter_a': 25366699,
#   'encounter_b': 27921263,
#   'similarity': {'demographics_sim': 0.3215686274509804,
#    'diagnoses_sim': 0.4930425867530345,
#    'labevents_sim': 0.1828743797723644,
#    'vitalsigns_sim': 0.17279557311321173,
#    'inputevents_sim': 0.09090909090909091}},
#  {'encounter_a': 25366699,
#   'encounter_b': 22904714,
#   'similarity': {'demographics_sim': 0.5607843137254902,
#    'diagnoses_sim': 0.36584273246193916,
#    'labevents_sim': 0.13998567269105908,
#    'vitalsigns_sim': 0.1825463733992083,
#    'inputevents_sim': 0.3076923076923077}},
#  {'encounter_a': 25366699,
#   'encounter_b': 25415625,
#   'similarity': {'demographics_sim': 0.611764705882353,
#    'diagnoses_sim': 0.3456450468816685,
#    'labevents_sim': 0.12709060729106286,
#    'vitalsigns_sim': 0.30196719171406544,
#    'inputevents_sim': 0.2857142857142857}},
#  {'encounter_a': 25366699,
#   'encounter_b': 25366699,
#   'similarity': {'demographics_sim': 1.0,
#    'diagnoses_sim': 1.0,
#    'labevents_sim': 1.0,
#    'vitalsigns_sim': 1.0,
#    'inputevents_sim': 1.0}},
#  {'encounter_a': 25366699,
#   'encounter_b': 21658149,
#   'similarity': {'demographics_sim': 0.2627450980392157,
#    'diagnoses_sim': 0.3417777437171539,
#    'labevents_sim': 0.1510966359055554,
#    'vitalsigns_sim': 0.03074923000200423,
#    'inputevents_sim': 0.041666666666666664}},
#  {'encounter_a': 25366699,
#   'encounter_b': 25155096,
#   'similarity': {'demographics_sim': 0.5294117647058824,
#    'diagnoses_sim': 0.2992081823076784,
#    'labevents_sim': 0.19296547762939925,
#    'vitalsigns_sim': 0.21277417210507119,
#    'inputevents_sim': 0.1}},
#  {'encounter_a': 25366699,
#   'encounter_b': 22130791,
#   'similarity': {'demographics_sim': 0.6590038314176245,
#    'diagnoses_sim': 0.43515383106828953,
#    'labevents_sim': 0.14821972208403728,
#    'vitalsigns_sim': 0.04827393999335152,
#    'inputevents_sim': 0.0967741935483871}},
#  {'encounter_a': 25366699,
#   'encounter_b': 20664607,
#   'similarity': {'demographics_sim': 0.27058823529411763,
#    'diagnoses_sim': 0.30519305811288705,
#    'labevents_sim': 0.17653179190578294,
#    'vitalsigns_sim': 0.22176600228080307,
#    'inputevents_sim': 0.2}},
#  {'encounter_a': 25366699,
#   'encounter_b': 29068519,
#   'similarity': {'demographics_sim': 0.29411764705882354,
#    'diagnoses_sim': 0.40008834962753087,
#    'labevents_sim': 0.1362158479948155,
#    'vitalsigns_sim': 0.1245598176460886,
#    'inputevents_sim': 0.06451612903225806}},
#  {'encounter_a': 25366699,
#   'encounter_b': 26717744,
#   'similarity': {'demographics_sim': 0.6274509803921569,
#    'diagnoses_sim': 0.3842414312124544,
#    'labevents_sim': 0.09130571810247104,
#    'vitalsigns_sim': 0.11256720834022173,
#    'inputevents_sim': 0.1}},
#  {'encounter_a': 25366699,
#   'encounter_b': 24061120,
#   'similarity': {'demographics_sim': 0.2745098039215686,
#    'diagnoses_sim': 0.19523748301594848,
#    'labevents_sim': 0.18140001311623125,
#    'vitalsigns_sim': 0.11040197750521748,
#    'inputevents_sim': 0.13636363636363635}},
#  {'encounter_a': 25366699,
#   'encounter_b': 29056733,
#   'similarity': {'demographics_sim': 0.2980392156862745,
#    'diagnoses_sim': 0.31822384162825923,
#    'labevents_sim': 0.15237631152013142,
#    'vitalsigns_sim': 0.24256242300836905,
#    'inputevents_sim': 0.11428571428571428}},
#  {'encounter_a': 25366699,
#   'encounter_b': 24080968,
#   'similarity': {'demographics_sim': 0.26666666666666666,
#    'diagnoses_sim': 0.4636395267200172,
#    'labevents_sim': 0.14878056264784498,
#    'vitalsigns_sim': 0.19705978375767363,
#    'inputevents_sim': 0.14285714285714285}},
#  {'encounter_a': 25366699,
#   'encounter_b': 28186950,
#   'similarity': {'demographics_sim': 0.2549019607843137,
#    'diagnoses_sim': 0.3776239271368854,
#    'labevents_sim': 0.09461397822066539,
#    'vitalsigns_sim': 0.11434813301922278,
#    'inputevents_sim': 0.12}},
#  {'encounter_a': 25366699,
#   'encounter_b': 21842619,
#   'similarity': {'demographics_sim': 0.592156862745098,
#    'diagnoses_sim': 0.39219157203075916,
#    'labevents_sim': 0.16210431020268312,
#    'vitalsigns_sim': 0.19290379357626744,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 25366699,
#   'encounter_b': 27779433,
#   'similarity': {'demographics_sim': 0.18823529411764706,
#    'diagnoses_sim': 0.3096380974289979,
#    'labevents_sim': 0.10185884009040486,
#    'vitalsigns_sim': 0.2539933304326825,
#    'inputevents_sim': 0.08333333333333333}},
#  {'encounter_a': 21658149,
#   'encounter_b': 21764330,
#   'similarity': {'demographics_sim': 0.3333333333333333,
#    'diagnoses_sim': 0.33389613611932173,
#    'labevents_sim': 0.14602746015691484,
#    'vitalsigns_sim': 0.2481275041223469,
#    'inputevents_sim': 0.125}},
#  {'encounter_a': 21658149,
#   'encounter_b': 24625361,
#   'similarity': {'demographics_sim': 0.20398009950248755,
#    'diagnoses_sim': 0.5852371282521143,
#    'labevents_sim': 0.12293740295861737,
#    'vitalsigns_sim': 0.10386747066270917,
#    'inputevents_sim': 0.2222222222222222}},
#  {'encounter_a': 21658149,
#   'encounter_b': 27370800,
#   'similarity': {'demographics_sim': 0.3190476190476191,
#    'diagnoses_sim': 0.457445342339136,
#    'labevents_sim': 0.1172008781366669,
#    'vitalsigns_sim': 0.06562643446123123,
#    'inputevents_sim': 0.26666666666666666}},
#  {'encounter_a': 21658149,
#   'encounter_b': 20532621,
#   'similarity': {'demographics_sim': 0.19402985074626866,
#    'diagnoses_sim': 0.24295172120159414,
#    'labevents_sim': 0.1656587825103582,
#    'vitalsigns_sim': 0.07275897518665862,
#    'inputevents_sim': 0.08571428571428572}},
#  {'encounter_a': 21658149,
#   'encounter_b': 27921263,
#   'similarity': {'demographics_sim': 0.6056910569105691,
#    'diagnoses_sim': 0.28956421072880806,
#    'labevents_sim': 0.1070390536509527,
#    'vitalsigns_sim': 0.09124224514469209,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 21658149,
#   'encounter_b': 22904714,
#   'similarity': {'demographics_sim': 0.2885572139303482,
#    'diagnoses_sim': 0.4600952175002424,
#    'labevents_sim': 0.10721952432692335,
#    'vitalsigns_sim': 0.11965763088267727,
#    'inputevents_sim': 0.25}},
#  {'encounter_a': 21658149,
#   'encounter_b': 25415625,
#   'similarity': {'demographics_sim': 0.3145539906103286,
#    'diagnoses_sim': 0.45071973899691675,
#    'labevents_sim': 0.11054931421387615,
#    'vitalsigns_sim': 0.03601870873960946,
#    'inputevents_sim': 0.047619047619047616}},
#  {'encounter_a': 21658149,
#   'encounter_b': 25366699,
#   'similarity': {'demographics_sim': 0.2627450980392157,
#    'diagnoses_sim': 0.3417777437171539,
#    'labevents_sim': 0.1510966359055554,
#    'vitalsigns_sim': 0.03074923000200423,
#    'inputevents_sim': 0.041666666666666664}},
#  {'encounter_a': 21658149,
#   'encounter_b': 21658149,
#   'similarity': {'demographics_sim': 1.0,
#    'diagnoses_sim': 1.0,
#    'labevents_sim': 1.0,
#    'vitalsigns_sim': 1.0,
#    'inputevents_sim': 1.0}},
#  {'encounter_a': 21658149,
#   'encounter_b': 25155096,
#   'similarity': {'demographics_sim': 0.24875621890547264,
#    'diagnoses_sim': 0.27056587507621327,
#    'labevents_sim': 0.13160606976142977,
#    'vitalsigns_sim': 0.07370366878894559,
#    'inputevents_sim': 0.043478260869565216}},
#  {'encounter_a': 21658149,
#   'encounter_b': 22130791,
#   'similarity': {'demographics_sim': 0.2567049808429119,
#    'diagnoses_sim': 0.5968324055337391,
#    'labevents_sim': 0.14788698987287105,
#    'vitalsigns_sim': 0.28386421937151085,
#    'inputevents_sim': 0.2702702702702703}},
#  {'encounter_a': 21658149,
#   'encounter_b': 20664607,
#   'similarity': {'demographics_sim': 0.6570048309178744,
#    'diagnoses_sim': 0.28690348982796343,
#    'labevents_sim': 0.1573501274454144,
#    'vitalsigns_sim': 0.07958260427636409,
#    'inputevents_sim': 0.041666666666666664}},
#  {'encounter_a': 21658149,
#   'encounter_b': 29068519,
#   'similarity': {'demographics_sim': 0.6311111111111111,
#    'diagnoses_sim': 0.6439362868076819,
#    'labevents_sim': 0.10480050741584436,
#    'vitalsigns_sim': 0.17256177545985799,
#    'inputevents_sim': 0.21052631578947367}},
#  {'encounter_a': 21658149,
#   'encounter_b': 26717744,
#   'similarity': {'demographics_sim': 0.29777777777777775,
#    'diagnoses_sim': 0.36816039109070126,
#    'labevents_sim': 0.13638886872161227,
#    'vitalsigns_sim': 0.2008006489773289,
#    'inputevents_sim': 0.24324324324324326}},
#  {'encounter_a': 21658149,
#   'encounter_b': 24061120,
#   'similarity': {'demographics_sim': 0.6523809523809524,
#    'diagnoses_sim': 0.49068456813677946,
#    'labevents_sim': 0.17021849158156369,
#    'vitalsigns_sim': 0.25005046716866147,
#    'inputevents_sim': 0.11764705882352941}},
#  {'encounter_a': 21658149,
#   'encounter_b': 29056733,
#   'similarity': {'demographics_sim': 0.6271929824561403,
#    'diagnoses_sim': 0.4730630108291713,
#    'labevents_sim': 0.12536510028064,
#    'vitalsigns_sim': 0.06685620616236541,
#    'inputevents_sim': 0.18181818181818182}},
#  {'encounter_a': 21658149,
#   'encounter_b': 24080968,
#   'similarity': {'demographics_sim': 0.6617647058823529,
# ...
#   'similarity': {'demographics_sim': 0.5435897435897435,
#    'diagnoses_sim': 0.4016419907425558,
#    'labevents_sim': 0.1807669225009611,
#    'vitalsigns_sim': 0.08372468281493337,
#    'inputevents_sim': 0.2413793103448276}},
#  {'encounter_a': 28186950,
#   'encounter_b': 27370800,
#   'similarity': {'demographics_sim': 0.6428571428571429,
#    'diagnoses_sim': 0.47343173158714763,
#    'labevents_sim': 0.1765725350962734,
#    'vitalsigns_sim': 0.14155180467406708,
#    'inputevents_sim': 0.3333333333333333}},
#  {'encounter_a': 28186950,
#   'encounter_b': 20532621,
#   'similarity': {'demographics_sim': 0.5333333333333333,
#    'diagnoses_sim': 0.14306258499267258,
#    'labevents_sim': 0.13635488470551554,
#    'vitalsigns_sim': 0.08566653380153234,
#    'inputevents_sim': 0.20588235294117646}},
#  {'encounter_a': 28186950,
#   'encounter_b': 27921263,
#   'similarity': {'demographics_sim': 0.9308943089430894,
#    'diagnoses_sim': 0.4324512714749733,
#    'labevents_sim': 0.15754150625911623,
#    'vitalsigns_sim': 0.17995193046341468,
#    'inputevents_sim': 0.23809523809523808}},
#  {'encounter_a': 28186950,
#   'encounter_b': 22904714,
#   'similarity': {'demographics_sim': 0.6307692307692307,
#    'diagnoses_sim': 0.5931881243486057,
#    'labevents_sim': 0.1270037366696663,
#    'vitalsigns_sim': 0.13111037157593644,
#    'inputevents_sim': 0.17857142857142858}},
#  {'encounter_a': 28186950,
#   'encounter_b': 25415625,
#   'similarity': {'demographics_sim': 0.3051643192488263,
#    'diagnoses_sim': 0.2773511206593506,
#    'labevents_sim': 0.16711310153668002,
#    'vitalsigns_sim': 0.12302633391200893,
#    'inputevents_sim': 0.13636363636363635}},
#  {'encounter_a': 28186950,
#   'encounter_b': 25366699,
#   'similarity': {'demographics_sim': 0.2549019607843137,
#    'diagnoses_sim': 0.3776239271368854,
#    'labevents_sim': 0.09461397822066539,
#    'vitalsigns_sim': 0.11434813301922278,
#    'inputevents_sim': 0.12}},
#  {'encounter_a': 28186950,
#   'encounter_b': 21658149,
#   'similarity': {'demographics_sim': 0.6567164179104478,
#    'diagnoses_sim': 0.42830970130116663,
#    'labevents_sim': 0.12935859510022837,
#    'vitalsigns_sim': 0.1796942209304936,
#    'inputevents_sim': 0.28125}},
#  {'encounter_a': 28186950,
#   'encounter_b': 25155096,
#   'similarity': {'demographics_sim': 0.25641025641025644,
#    'diagnoses_sim': 0.4368993753128871,
#    'labevents_sim': 0.12344353156757337,
#    'vitalsigns_sim': 0.135860569963158,
#    'inputevents_sim': 0.08}},
#  {'encounter_a': 28186950,
#   'encounter_b': 22130791,
#   'similarity': {'demographics_sim': 0.5823754789272031,
#    'diagnoses_sim': 0.4316401187419398,
#    'labevents_sim': 0.17347278540046257,
#    'vitalsigns_sim': 0.26607366321748444,
#    'inputevents_sim': 0.3157894736842105}},
#  {'encounter_a': 28186950,
#   'encounter_b': 20664607,
#   'similarity': {'demographics_sim': 0.6473429951690821,
#    'diagnoses_sim': 0.3638093926005567,
#    'labevents_sim': 0.12233788085314812,
#    'vitalsigns_sim': 0.09053493061564952,
#    'inputevents_sim': 0.12}},
#  {'encounter_a': 28186950,
#   'encounter_b': 29068519,
#   'similarity': {'demographics_sim': 0.6222222222222222,
#    'diagnoses_sim': 0.4882303805096714,
#    'labevents_sim': 0.24663471822243901,
#    'vitalsigns_sim': 0.17248456255976072,
#    'inputevents_sim': 0.2564102564102564}},
#  {'encounter_a': 28186950,
#   'encounter_b': 26717744,
#   'similarity': {'demographics_sim': 0.6222222222222222,
#    'diagnoses_sim': 0.29102398483270125,
#    'labevents_sim': 0.17764508224067346,
#    'vitalsigns_sim': 0.2518469228769414,
#    'inputevents_sim': 0.3611111111111111}},
#  {'encounter_a': 28186950,
#   'encounter_b': 24061120,
#   'similarity': {'demographics_sim': 0.9761904761904762,
#    'diagnoses_sim': 0.30533797190698847,
#    'labevents_sim': 0.13544781363106012,
#    'vitalsigns_sim': 0.20816206618843205,
#    'inputevents_sim': 0.28125}},
#  {'encounter_a': 28186950,
#   'encounter_b': 29056733,
#   'similarity': {'demographics_sim': 0.618421052631579,
#    'diagnoses_sim': 0.5333387396467337,
#    'labevents_sim': 0.15388976604398352,
#    'vitalsigns_sim': 0.16790552625335148,
#    'inputevents_sim': 0.30952380952380953}},
#  {'encounter_a': 28186950,
#   'encounter_b': 24080968,
#   'similarity': {'demographics_sim': 0.6519607843137255,
#    'diagnoses_sim': 0.4909534156379959,
#    'labevents_sim': 0.2234559313488941,
#    'vitalsigns_sim': 0.2489181458630471,
#    'inputevents_sim': 0.043478260869565216}},
#  {'encounter_a': 28186950,
#   'encounter_b': 28186950,
#   'similarity': {'demographics_sim': 1.0,
#    'diagnoses_sim': 1.0,
#    'labevents_sim': 1.0,
#    'vitalsigns_sim': 1.0,
#    'inputevents_sim': 1.0}},
#  {'encounter_a': 28186950,
#   'encounter_b': 21842619,
#   'similarity': {'demographics_sim': 0.6616161616161617,
#    'diagnoses_sim': 0.43413567989412105,
#    'labevents_sim': 0.14402654415649738,
#    'vitalsigns_sim': 0.12902891888063014,
#    'inputevents_sim': 0.15384615384615385}},
#  {'encounter_a': 28186950,
#   'encounter_b': 27779433,
#   'similarity': {'demographics_sim': 0.9128205128205128,
#    'diagnoses_sim': 0.3088154248094629,
#    'labevents_sim': 0.16736840348062448,
#    'vitalsigns_sim': 0.16797991681657903,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 21842619,
#   'encounter_b': 21764330,
#   'similarity': {'demographics_sim': 0.9950248756218906,
#    'diagnoses_sim': 0.5419579096593792,
#    'labevents_sim': 0.1661560516437127,
#    'vitalsigns_sim': 0.10840208807712698,
#    'inputevents_sim': 0.3333333333333333}},
#  {'encounter_a': 21842619,
#   'encounter_b': 24625361,
#   'similarity': {'demographics_sim': 0.8737373737373737,
#    'diagnoses_sim': 0.3619929246486977,
#    'labevents_sim': 0.12096806014318878,
#    'vitalsigns_sim': 0.13893663686983712,
#    'inputevents_sim': 0.29411764705882354}},
#  {'encounter_a': 21842619,
#   'encounter_b': 27370800,
#   'similarity': {'demographics_sim': 0.9809523809523809,
#    'diagnoses_sim': 0.4401371386573613,
#    'labevents_sim': 0.13323764291800952,
#    'vitalsigns_sim': 0.0789871698762086,
#    'inputevents_sim': 0.09523809523809523}},
#  {'encounter_a': 21842619,
#   'encounter_b': 20532621,
#   'similarity': {'demographics_sim': 0.8636363636363636,
#    'diagnoses_sim': 0.08888351672291628,
#    'labevents_sim': 0.10832054365068954,
#    'vitalsigns_sim': 0.13458111314211077,
#    'inputevents_sim': 0.125}},
#  {'encounter_a': 21842619,
#   'encounter_b': 27921263,
#   'similarity': {'demographics_sim': 0.6016260162601627,
#    'diagnoses_sim': 0.5111357962993197,
#    'labevents_sim': 0.14744124687442103,
#    'vitalsigns_sim': 0.09396438164013557,
#    'inputevents_sim': 0.08571428571428572}},
#  {'encounter_a': 21842619,
#   'encounter_b': 22904714,
#   'similarity': {'demographics_sim': 0.9595959595959596,
#    'diagnoses_sim': 0.47361516329677555,
#    'labevents_sim': 0.11615298082210454,
#    'vitalsigns_sim': 0.2063315322610879,
#    'inputevents_sim': 0.35714285714285715}},
#  {'encounter_a': 21842619,
#   'encounter_b': 25415625,
#   'similarity': {'demographics_sim': 0.6431924882629108,
#    'diagnoses_sim': 0.31925279509432436,
#    'labevents_sim': 0.12916504143382457,
#    'vitalsigns_sim': 0.1470776305707149,
#    'inputevents_sim': 0.2222222222222222}},
#  {'encounter_a': 21842619,
#   'encounter_b': 25366699,
#   'similarity': {'demographics_sim': 0.592156862745098,
#    'diagnoses_sim': 0.39219157203075916,
#    'labevents_sim': 0.16210431020268312,
#    'vitalsigns_sim': 0.19290379357626744,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 21842619,
#   'encounter_b': 21658149,
#   'similarity': {'demographics_sim': 0.3283582089552239,
#    'diagnoses_sim': 0.4447318014646632,
#    'labevents_sim': 0.2321709928569387,
#    'vitalsigns_sim': 0.11602595314392586,
#    'inputevents_sim': 0.17391304347826086}},
#  {'encounter_a': 21842619,
#   'encounter_b': 25155096,
#   'similarity': {'demographics_sim': 0.5858585858585859,
#    'diagnoses_sim': 0.3457018259674164,
#    'labevents_sim': 0.12035817557497318,
#    'vitalsigns_sim': 0.17422397085622643,
#    'inputevents_sim': 0.08333333333333333}},
#  {'encounter_a': 21842619,
#   'encounter_b': 22130791,
#   'similarity': {'demographics_sim': 0.9195402298850575,
#    'diagnoses_sim': 0.45580336804024313,
#    'labevents_sim': 0.16746815948120922,
#    'vitalsigns_sim': 0.11642082086126995,
#    'inputevents_sim': 0.2}},
#  {'encounter_a': 21842619,
#   'encounter_b': 20664607,
#   'similarity': {'demographics_sim': 0.31884057971014496,
#    'diagnoses_sim': 0.37448033116010515,
#    'labevents_sim': 0.1654343320443685,
#    'vitalsigns_sim': 0.14007322783912765,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 21842619,
#   'encounter_b': 29068519,
#   'similarity': {'demographics_sim': 0.29333333333333333,
#    'diagnoses_sim': 0.3190896795904621,
#    'labevents_sim': 0.14296764417830227,
#    'vitalsigns_sim': 0.14857413691071736,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 21842619,
#   'encounter_b': 26717744,
#   'similarity': {'demographics_sim': 0.96,
#    'diagnoses_sim': 0.39024126104231144,
#    'labevents_sim': 0.19759312025968548,
#    'vitalsigns_sim': 0.12194273603837852,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 21842619,
#   'encounter_b': 24061120,
#   'similarity': {'demographics_sim': 0.6476190476190476,
#    'diagnoses_sim': 0.21365055075139575,
#    'labevents_sim': 0.14494081368734996,
#    'vitalsigns_sim': 0.16940989381341268,
#    'inputevents_sim': 0.22727272727272727}},
#  {'encounter_a': 21842619,
#   'encounter_b': 29056733,
#   'similarity': {'demographics_sim': 0.2894736842105263,
#    'diagnoses_sim': 0.2734518921715202,
#    'labevents_sim': 0.10442458297576604,
#    'vitalsigns_sim': 0.11955283861332286,
#    'inputevents_sim': 0.07894736842105263}},
#  {'encounter_a': 21842619,
#   'encounter_b': 24080968,
#   'similarity': {'demographics_sim': 0.3235294117647059,
#    'diagnoses_sim': 0.6123717338935394,
#    'labevents_sim': 0.24282349901500644,
#    'vitalsigns_sim': 0.11621994150982527,
#    'inputevents_sim': 0.1111111111111111}},
#  {'encounter_a': 21842619,
#   'encounter_b': 28186950,
#   'similarity': {'demographics_sim': 0.6616161616161617,
#    'diagnoses_sim': 0.43413567989412105,
#    'labevents_sim': 0.14402654415649738,
#    'vitalsigns_sim': 0.12902891888063014,
#    'inputevents_sim': 0.15384615384615385}},
#  {'encounter_a': 21842619,
#   'encounter_b': 21842619,
#   'similarity': {'demographics_sim': 1.0,
#    'diagnoses_sim': 1.0,
#    'labevents_sim': 1.0,
#    'vitalsigns_sim': 1.0,
#    'inputevents_sim': 1.0}},
#  {'encounter_a': 21842619,
#   'encounter_b': 27779433,
#   'similarity': {'demographics_sim': 0.5757575757575758,
#    'diagnoses_sim': 0.2742622161635963,
#    'labevents_sim': 0.1502537874853239,
#    'vitalsigns_sim': 0.14741308094996802,
#    'inputevents_sim': 0.07692307692307693}},
#  {'encounter_a': 27779433,
#   'encounter_b': 21764330,
#   'similarity': {'demographics_sim': 0.572139303482587,
#    'diagnoses_sim': 0.39019037847858373,
#    'labevents_sim': 0.19403278549600939,
#    'vitalsigns_sim': 0.18766622203590672,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 27779433,
#   'encounter_b': 24625361,
#   'similarity': {'demographics_sim': 0.6180555555555556,
#    'diagnoses_sim': 0.10624441764329381,
#    'labevents_sim': 0.15266699955648969,
#    'vitalsigns_sim': 0.1706832458351286,
#    'inputevents_sim': 0.21428571428571427}},
#  {'encounter_a': 27779433,
#   'encounter_b': 27370800,
#   'similarity': {'demographics_sim': 0.5619047619047619,
#    'diagnoses_sim': 0.22828980320431277,
#    'labevents_sim': 0.15067741001780013,
#    'vitalsigns_sim': 0.2303127887514618,
#    'inputevents_sim': 0.3181818181818182}},
#  {'encounter_a': 27779433,
#   'encounter_b': 20532621,
#   'similarity': {'demographics_sim': 0.6041666666666666,
#    'diagnoses_sim': 0.11694028387190389,
#    'labevents_sim': 0.1318558701433919,
#    'vitalsigns_sim': 0.21823827844322366,
#    'inputevents_sim': 0.3}},
#  {'encounter_a': 27779433,
#   'encounter_b': 27921263,
#   'similarity': {'demographics_sim': 0.8617886178861789,
#    'diagnoses_sim': 0.3979742137107943,
#    'labevents_sim': 0.0737567768884539,
#    'vitalsigns_sim': 0.19691844982259815,
#    'inputevents_sim': 0.28205128205128205}},
#  {'encounter_a': 27779433,
#   'encounter_b': 22904714,
#   'similarity': {'demographics_sim': 0.6091954022988506,
#    'diagnoses_sim': 0.22620580070171434,
#    'labevents_sim': 0.14019508589878288,
#    'vitalsigns_sim': 0.14632857330424762,
#    'inputevents_sim': 0.19230769230769232}},
#  {'encounter_a': 27779433,
#   'encounter_b': 25415625,
#   'similarity': {'demographics_sim': 0.22535211267605634,
#    'diagnoses_sim': 0.21654365366253975,
#    'labevents_sim': 0.1265112898357555,
#    'vitalsigns_sim': 0.21965760048878286,
#    'inputevents_sim': 0.045454545454545456}},
#  {'encounter_a': 27779433,
#   'encounter_b': 25366699,
#   'similarity': {'demographics_sim': 0.18823529411764706,
#    'diagnoses_sim': 0.3096380974289979,
#    'labevents_sim': 0.10185884009040486,
#    'vitalsigns_sim': 0.2539933304326825,
#    'inputevents_sim': 0.08333333333333333}},
#  {'encounter_a': 27779433,
#   'encounter_b': 21658149,
#   'similarity': {'demographics_sim': 0.572139303482587,
#    'diagnoses_sim': 0.22977005963703676,
#    'labevents_sim': 0.14037153539092515,
#    'vitalsigns_sim': 0.10731767549545856,
#    'inputevents_sim': 0.18181818181818182}},
#  {'encounter_a': 27779433,
#   'encounter_b': 25155096,
#   'similarity': {'demographics_sim': 0.32,
#    'diagnoses_sim': 0.30130417869648113,
#    'labevents_sim': 0.20117201794028253,
#    'vitalsigns_sim': 0.19817569339540894,
#    'inputevents_sim': 0.041666666666666664}},
#  {'encounter_a': 27779433,
#   'encounter_b': 22130791,
#   'similarity': {'demographics_sim': 0.5172413793103449,
#    'diagnoses_sim': 0.26014143505179743,
#    'labevents_sim': 0.11079628333142964,
#    'vitalsigns_sim': 0.12552864635497232,
#    'inputevents_sim': 0.3333333333333333}},
#  {'encounter_a': 27779433,
#   'encounter_b': 20664607,
#   'similarity': {'demographics_sim': 0.5652173913043478,
#    'diagnoses_sim': 0.1738540443651655,
#    'labevents_sim': 0.1602349589745202,
#    'vitalsigns_sim': 0.21904652770727437,
#    'inputevents_sim': 0.13043478260869565}},
#  {'encounter_a': 27779433,
#   'encounter_b': 29068519,
#   'similarity': {'demographics_sim': 0.5466666666666666,
#    'diagnoses_sim': 0.22422974272091098,
#    'labevents_sim': 0.16631120530848895,
#    'vitalsigns_sim': 0.12771172180678558,
#    'inputevents_sim': 0.175}},
#  {'encounter_a': 27779433,
#   'encounter_b': 26717744,
#   'similarity': {'demographics_sim': 0.5466666666666666,
#    'diagnoses_sim': 0.24355535991439436,
#    'labevents_sim': 0.14420371915811456,
#    'vitalsigns_sim': 0.1611733839161654,
#    'inputevents_sim': 0.42424242424242425}},
#  {'encounter_a': 27779433,
#   'encounter_b': 24061120,
#   'similarity': {'demographics_sim': 0.8952380952380953,
#    'diagnoses_sim': 0.12573143070790746,
#    'labevents_sim': 0.0981881028689928,
#    'vitalsigns_sim': 0.11403162970673131,
#    'inputevents_sim': 0.25806451612903225}},
#  {'encounter_a': 27779433,
#   'encounter_b': 29056733,
#   'similarity': {'demographics_sim': 0.543859649122807,
#    'diagnoses_sim': 0.13995835274481397,
#    'labevents_sim': 0.11862142693709568,
#    'vitalsigns_sim': 0.3715830748122277,
#    'inputevents_sim': 0.358974358974359}},
#  {'encounter_a': 27779433,
#   'encounter_b': 24080968,
#   'similarity': {'demographics_sim': 0.5686274509803921,
#    'diagnoses_sim': 0.3176025313080741,
#    'labevents_sim': 0.18641617649750247,
#    'vitalsigns_sim': 0.14993364890414868,
#    'inputevents_sim': 0.0}},
#  {'encounter_a': 27779433,
#   'encounter_b': 28186950,
#   'similarity': {'demographics_sim': 0.9128205128205128,
#    'diagnoses_sim': 0.3088154248094629,
#    'labevents_sim': 0.16736840348062448,
#    'vitalsigns_sim': 0.16797991681657903,
#    'inputevents_sim': 0.16666666666666666}},
#  {'encounter_a': 27779433,
#   'encounter_b': 21842619,
#   'similarity': {'demographics_sim': 0.5757575757575758,
#    'diagnoses_sim': 0.2742622161635963,
#    'labevents_sim': 0.1502537874853239,
#    'vitalsigns_sim': 0.14741308094996802,
#    'inputevents_sim': 0.07692307692307693}},
#  {'encounter_a': 27779433,
#   'encounter_b': 27779433,
#   'similarity': {'demographics_sim': 1.0,
#    'diagnoses_sim': 1.0,
#    'labevents_sim': 1.0,
#    'vitalsigns_sim': 1.0,
#    'inputevents_sim': 1.0}}]
